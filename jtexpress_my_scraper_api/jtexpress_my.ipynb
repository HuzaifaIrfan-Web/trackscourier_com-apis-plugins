# %%
from bs4 import BeautifulSoup
import requests

# %%
tnum=620000295758173

# %%
url=f'https://www.jtexpress.my/tracking/{tnum}'

# %%
r = requests.get(url, verify=False)
# Out:
# C:\Users\Admi\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.jtexpress.my'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <title>J&amp;T Express</title>
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#
#     <link href="https://www.jtexpress.my/icon/favicon.ico" rel="icon">
#
#
#     <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/css/bootstrap.min.css" rel="stylesheet"
#         integrity="sha384-EVSTQN3/azprG1Anm3QDgpJLIm9Nao0Yz1ztcQTwFspd3yD65VohhpuuCOmLASjC" crossorigin="anonymous">
#     <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/js/bootstrap.bundle.min.js"
#         integrity="sha384-MrcW6ZMFYlzcLA8Nl+NtUVF0sA7MsXsP1UyJoMp4YLEuNSfAP+JcXn/tWtIaxVXM" crossorigin="anonymous">
#     </script>
#     <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.5.1/jquery.min.js"></script>
#     <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.9.0/css/all.css">
#     <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.9.0/css/v4-shims.css">
#
#     <!-- Global site tag (gtag.js) - Google Analytics -->
#     <script async src="https://www.googletagmanager.com/gtag/js?id=UA-127851323-1"></script>
#     <script>
#         window.dataLayer = window.dataLayer || [];
#
#         function gtag() {
#             dataLayer.push(arguments);
#         }
#         gtag('js', new Date());
#
#         gtag('config', 'UA-127851323-1');
#     </script>
#
#
#     <link href="https://www.jtexpress.my/css/app.css" rel="stylesheet">
#     <link href="https://www.jtexpress.my/css/style.css" rel="stylesheet">
#
#
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/viewerjs/1.10.1/viewer.min.js"></script>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/viewerjs/1.10.1/viewer.css">
#
#     <style>
#         .div-date {
#             background: red;
#             color: white;
#             border-radius: 10px;
#             text-align: center;
#             font-size: 1.5rem;
#             padding: 5%;
#             margin: 5%
#         }
#
#         .div-parcel-info {
#             margin: 2% auto;
#             border-radius: 10px;
#         }
#
#         .accordion-button::after {
#             background-image: none;
#             content: '\f0da';
#             font-family: 'Font Awesome 5 Free';
#             width: initial;
#             font-size: 1.1rem;
#             padding-top: 2px;
#             height: initial;
#             font-weight: 900;
#         }
#
#         .accordion-button:not(.collapsed)::after {
#             background-image: none;
#             transform: rotate(90deg);
#         }
#
#         .accordion-button {
#             border: 0;
#         }
#
#         .accordion-button:focus,
#         .accordion-button:active {
#             outline: 0;
#             box-shadow: 0 0 0 0;
#         }
#
#         .accordion-header,
#         .accordion-collapse {
#             border: 0;
#             background-color: #f2f2f2;
#         }
#
#         .accordion-button:not(.collapsed) {
#             color: initial;
#             background-color: initial;
#         }
#
#         /* Chrome, Safari, Edge, Opera */
#         input::-webkit-outer-spin-button,
#         input::-webkit-inner-spin-button {
#             -webkit-appearance: none;
#             margin: 0;
#         }
#
#         /* Firefox */
#         input[type=number] {
#             -moz-appearance: textfield;
#         }
#
#         ul li i:after {
#             content: "";
#             width: 100%;
#             transform: translateY(7px);
#             height: 1px;
#             background: #ccc;
#             position: absolute;
#
#         }
#
#         ul li:last-child i:after {
#             width: 0px;
#         }
#
#         ul li i.active:after {
#             content: "";
#             width: 100%;
#             transform: translateY(7px);
#             height: 1px;
#             background: #32CD32;
#             position: absolute;
#         }
#
#         ul li:last-child i.active:after {
#             width: 0px;
#         }
#
#         i.active {
#             color: #32CD32 !important;
#         }
#
#         ul li img {
#             filter: grayscale(100%);
#         }
#
#         ul li img.active {
#             filter: grayscale(0%);
#         }
#
#         .btn-toggle-accordion:focus {
#             outline: none;
#             box-shadow: none;
#         }
#
#         @media (max-width: 360px) {
#             ul li p {
#                 font-size: 0.8rem;
#             }
#         }
#
#         @media (max-width: 300px) {
#             ul li p {
#                 font-size: 0.7rem;
#             }
#
#             ul li img {
#                 width: 2rem;
#             }
#         }
#
#         @media (max-width: 267px) {
#             ul li i:after {
#                 content: "";
#                 width: 0;
#             }
#
#             ul li i.active:after {
#                 content: "";
#                 width: 0;
#             }
#         }
#
#     </style>
# </head>
#
#
#
# <body style="margin:0;">
#
#
#     <style>
#     .dropdown-item:hover {
#         background: red;
#         color: white;
#     }
#
#     .nav-menu {
#         margin-right: 10px;
#     }
#
#     nav.navbar>*,
#     .nav-link {
#         text-transform: uppercase;
#     }
#
# </style>
# <nav class="navbar navbar-expand-lg navbar-dark bg-primary fixed-top">
#     <div class="container-fluid">
#         <div style="margin-left:40px;" class="d-none d-lg-inline-block"></div>
#         <a class="navbar-brand" href="https://www.jtexpress.my"><img src="https://www.jtexpress.my/img/jnt.png" alt="logo"
#                 style="width:100px;height:40px;object-fit:scale-down;"></a>
#         <button class="navbar-toggler" type="button" data-bs-toggle="collapse" data-bs-target="#navbarTogglerDemo02"
#             aria-controls="navbarTogglerDemo02" aria-expanded="false" aria-label="Toggle navigation">
#             <span class="navbar-toggler-icon"></span>
#         </button>
#         <div class="collapse navbar-collapse" id="navbarTogglerDemo02" style="font-size: 13px;">
#             <ul class="navbar-nav me-auto mb-2 mb-lg-0">
#                 <li class="nav-item dropdown">
#                     <a class="nav-link text-light nav-menu" id="shippingorder" role="button" data-bs-toggle="dropdown"
#                         aria-expanded="false">
#                         Shipping
#                     </a>
#                     <ul class="dropdown-menu" aria-labelledby="shippingorder">
#                         <li><a href="https://www.jtexpress.my/order"
#                                 class="dropdown-item">Domestic Shipping</a></li>
#                         <li><a href="https://www.jtexpress.my/international"
#                                 class="dropdown-item">International Shipping</a></li>
#                         <li><a href="https://www.jtexpress.my/mps"
#                                 class="dropdown-item">Multi-Piece Shipment</a></li>
#                         <li><a href="https://www.jtexpress.my/sea-freight"
#                                 class="dropdown-item">Sea Freight</a></li>
#
#                     </ul>
#                 </li>
#                 <li class="nav-item dropdown">
#                     <a class="nav-link text-light nav-menu" id="services" role="button" data-bs-toggle="dropdown"
#                         aria-expanded="false">
#                         Services
#                     </a>
#                     <ul class="dropdown-menu" aria-labelledby="services">
#                         <li><a href="https://www.jtexpress.my/tracking"
#                                 class="dropdown-item">Track &amp; Trace</a></li>
#                         <li><a href="https://www.jtexpress.my/shipping-rates"
#                                 class="dropdown-item">Shipping Rates</a></li>
#                         <li><a href="https://www.jtexpress.my/location"
#                                 class="dropdown-item">Location</a></li>
#                         <li><a href="https://www.jtexpress.my/services"
#                                 class="dropdown-item">Service Types</a></li>
#                         <li><a href="https://www.jtexpress.my/delivery-time"
#                                 class="dropdown-item">Delivery Time</a></li>
#                         <li><a href="https://www.jtexpress.my/prohibited/domestic"
#                                 class="dropdown-item">Prohibited (Domestic)</a></li>
#
#                         <li><a href="https://www.jtexpress.my/receiver-address-update"
#                                 class="dropdown-item">Delivery Address Update</a>
#                         </li>
#                     </ul>
#                 </li>
#                 <li class="nav-item dropdown">
#                     <a class="nav-link text-light nav-menu" id="joinus" role="button" data-bs-toggle="dropdown"
#                         aria-expanded="false">
#                         Join Us
#                     </a>
#                     <ul class="dropdown-menu" aria-labelledby="joinus">
#                         <li><a href="https://www.jtexpress.my/e-commerce"
#                                 class="dropdown-item">E-Commerce</a></li>
#                         <li><a href="https://www.jtexpress.my/courier-point"
#                                 class="dropdown-item">Premium Courier Point</a></li>
#                         <li><a href="https://www.jtexpress.my/vip"
#                                 class="dropdown-item">VIP</a></li>
#                         <li><a href="https://job.jtexpress.my/" target="_blank"
#                                 class="dropdown-item">Part-Timer</a>
#                         </li>
#                     </ul>
#                 </li>
#             </ul>
#
#             <ul class="navbar-nav ms-auto mb-lg-0">
#                                     <li class="nav-item">
#                         <a href="https://www.jtexpress.my/login"
#                             class="nav-link text-light nav-menu">Login</a>
#                     </li>
#                                 <li class="nav-item dropdown pe-2">
#                     <a class="nav-link text-light" href="#" role="button" data-bs-toggle="dropdown" id="language"
#                         aria-expanded="false">
#                         LANGUAGE
#                     </a>
#                     <ul class="dropdown-menu dropdown-menu-end" aria-labelledby="language">
#                         <li><a class="dropdown-item" style="font-size: 13px;"
#                                 href="https://www.jtexpress.my/change-language/en">ENGLISH</a>
#                         </li>
#                         <li><a class="dropdown-item" style="font-size: 13px;"
#                                 href="https://www.jtexpress.my/change-language/zh_CN">中文</a></li>
#                         <li><a class="dropdown-item" style="font-size: 13px;"
#                                 href="https://www.jtexpress.my/change-language/ms">B.MALAYSIA</a>
#                         </li>
#                     </ul>
#                 </li>
#
#             </ul>
#         </div>
#     </div>
# </nav>
#     <div id="main-container" style="min-height:100vh;position: relative; margin-top:66px;padding-top:30px">
#         <div id="wrapper">
#             <div class="container-fluid custom-page-container">
#                     <div class="row">
#         <div class="col-12 col-sm-12 col-md-9 col-lg-8 col-xl-8 mx-auto text-center mb-2">
#             <h3 class="text-center">Track &amp; Trace</h3>
#             <form id="form-tracking" action="https://www.jtexpress.my/tracking" method="POST">
#                 <input type="hidden" name="_token" value="HJrY3QDtqXPGWb8sQxf35lb4bh5rCGJ1fhzsQUd6">                <div class="input-group mb-3">
#                     <input type="text" class="form-control p-4" placeholder="E.g.: 600000000001,600000000002 "
#                         aria-label="E.g.: 600000000001,600000000002 " aria-describedby="basic-addon2" name="wb" id="wb"
#                         required="required" style="border-top-left-radius: 15px;border-bottom-left-radius: 15px;"
#                          value="620000295758173" >
#                     <button id="btn-form-tracking-submit" class="btn btn-primary" type="submit"
#                         style="width:80px;border-top-right-radius: 15px;border-bottom-right-radius: 15px;">GO</button>
#                 </div>
#                 <div class="text-center">Enter your waybill number (separated by comma). Available up to 10 waybills.
#                 </div>
#             </form>
#
#             <div id="tracking-info">
#                  <div class="accordion accordion-flush">
#
#                 <div class="accordion-item my-4 shadow" style="border-radius:15px;">
#                     <div class="accordion-header" style="background:white;border-radius:15px;">
#                         <div class="p-3"
#                             style="background:#e60000;color:white;border-top-left-radius:15px;border-top-right-radius:15px;">
#                             <div class="text-start">
#                                 <div class="fw-bold">620000295758173&zwj;</div>
#                             </div>
#                             <div class="row">
#                                 <div class="col-12 text-start">
#                                     SELANGOR
#                                     <i class="fas fa-arrow-right mx-2"></i>
#                                     KELANTAN
#                                 </div>
#                             </div>
#                         </div>
#
#                         <div class="row mt-4">
#                             <div style=" margin:0;padding:0;">
#                                                                 <ul class="delivered" style="width:100%;margin:0;padding:0;">
#                                     <li class="d-inline-block position-relative">
#                                         <img src="https://www.jtexpress.my/img/tracking-pickedup.png" alt="" width="50px">
#                                         <p class="px-2 px-md-3 px-lg-3 px-xl-5">Picked Up
#                                         </p>
#                                         <i class="fa fa-circle" style="color:#acacac;"></i>
#                                     </li>
#                                     <li class="d-inline-block position-relative">
#                                         <img src="https://www.jtexpress.my/img/tracking-transit.png" alt="" width="50px">
#                                         <p class="px-2 px-md-3 px-lg-3 px-xl-5">In Transit
#                                         </p>
#                                         <i class="fa fa-circle" style="color:#acacac;"></i>
#                                     </li>
#                                     <li class="d-inline-block position-relative">
#                                         <img src="https://www.jtexpress.my/img/tracking-delivery.png" alt="" width="50px">
#                                         <p class="px-2 px-md-3 px-lg-3 px-xl-5">Delivery
#                                         </p>
#                                         <i class="fa fa-circle" style="color:#acacac;"></i>
#                                     </li>
#                                     <li class="d-inline-block position-relative">
#                                         <img src="https://www.jtexpress.my/img/tracking-delivered.png" alt="" width="50px">
#                                         <p class="px-2 px-md-3 px-lg-3 px-xl-5">Delivered
#                                         </p>
#                                         <i class="fa fa-circle" style="color:#acacac;"></i>
#                                     </li>
#                                 </ul>
#                             </div>
#                         </div>
#
#                         <div class="text-center mx-auto mb-3 fw-light h3"> Delivered</div>
#                         <div class="text-center mx-auto mb-3 fw-light h6">
#
#                         </div>
#
#                                                     <div class="row mb-3">
#                                 <div class="col-10 mx-auto">
#                                     <div class="d-inline-block rounded shadow-sm mt-2"
#                                         style="color:white;background:#acacac;">
#                                         <div class="d-flex">
#                                             <div class="d-flex rounded"
#                                                 style="background:white;border:1px solid #acacac;">
#                                                 <div class="align-self-center img-responsive">
#                                                     <img src="https://openweathermap.org/img/wn/04d@2x.png"
#                                                         style="width:100%;">
#                                                 </div>
#                                             </div>
#                                             <div
#                                                 class="
#                                                         row ml-1">
#                                                 <div class="col-12 col-sm-4 text-start align-self-center px-2 px-sm-3 ms-2"
#                                                     style="border-right:1px solid white;">
#                                                     <span
#                                                         class="text-nowrap pe-1">03 Oct</span>
#                                                     <span
#                                                         class="text-nowrap">3:12 PM</span>
#                                                 </div>
#                                                 <div
#                                                     class="col-11 col-sm-7 text-start align-self-center ms-2 px-2 px-md-3">
#                                                     <div style="font-size:1.05rem;text-transform: capitalize;">
#                                                         overcast clouds
#                                                     </div>
#                                                     <div style="font-size:0.8rem">
#                                                         Kampung Lemal</div>
#                                                     <div style="font-size:0.8rem">
#                                                         PASIR MAS</div>
#                                                 </div>
#                                             </div>
#
#                                         </div>
#                                     </div>
#                                 </div>
#                             </div>
#
#                         <div class="mx-3">
#
#
#                         </div>
#
#                         <div id="collapse-0" class="accordion-collapse collapse rounded-bottom">
#                             <div class="accordion-body p-0">
#
#                                 <div class="" style=" background:white">
#                                                                             <div class=" row">
#                                             <div class="col-12 col-sm-4">
#                                                 <div class="text-sm-end fs-5 pt-3" style="color:#acacac;">
#                                                     2021-09-10, Friday
#                                                 </div>
#                                             </div>
#                                         </div>
#                                         <div class="container text-start p-1 pt-3" style="background: white;">
#                                                                                             <div class="row">
#                                                     <div class="col-4 text-end" style="border-right:1px solid #acacac;">
#                                                         <div class="fw-b mt-3">
#                                                             05:34 PM
#                                                         </div>
#                                                     </div>
#                                                     <div class="col-7 mt-3">
#                                                         <b style="color:#e60000;">Delivered</b>
#                                                         <div class="fw-light">
#                                                             Drop Point CDC GAUNG LATI 327
#                                                         </div>
#                                                                                                                     <div>
#                                                                 <button class="btn btn-sm btn-primary btn-pod"
#                                                                     sender="$2y$10$O8qgaGYCUP90dLFLy344UOTp9V2zeLOaXI8CLNbMh1WkjvOxTJXPe"
#                                                                     receiver="$2y$10$s0w.Rw2aA4aKwfesy0Kdi.cgaC2JZ8vrjauxo5dUNBzUAvJD6N1tK"
#                                                                     wb="620000295758173"><i
#                                                                         class="fas fa-image me-2"></i>
#                                                                     Proof of Delivery
#                                                                 </button>
#                                                             </div>
#                                                                                                                                                                     </div>
#                                                 </div>
#                                                                                             <div class="row">
#                                                     <div class="col-4 text-end" style="border-right:1px solid #acacac;">
#                                                         <div class="fw-b mt-3">
#                                                             10:57 AM
#                                                         </div>
#                                                     </div>
#                                                     <div class="col-7 mt-3">
#                                                         <b style="color:#e60000;">Delivery</b>
#                                                         <div class="fw-light">
#                                                             Drop Point CDC GAUNG LATI 327
#                                                         </div>
#                                                                                                                                                                     </div>
#                                                 </div>
#                                                                                             <div class="row">
#                                                     <div class="col-4 text-end" style="border-right:1px solid #acacac;">
#                                                         <div class="fw-b mt-3">
#                                                             09:11 AM
#                                                         </div>
#                                                     </div>
#                                                     <div class="col-7 mt-3">
#                                                         <b style="color:#e60000;">Inbound</b>
#                                                         <div class="fw-light">
#                                                             Drop Point CDC GAUNG LATI 327
#                                                         </div>
#                                                                                                                                                                     </div>
#                                                 </div>
#                                                                                     </div>
#                                                                             <div class=" row">
#                                             <div class="col-12 col-sm-4">
#                                                 <div class="text-sm-end fs-5 pt-3" style="color:#acacac;">
#                                                     2021-09-09, Thursday
#                                                 </div>
#                                             </div>
#                                         </div>
#                                         <div class="container text-start p-1 pt-3" style="background: white;">
#                                                                                             <div class="row">
#                                                     <div class="col-4 text-end" style="border-right:1px solid #acacac;">
#                                                         <div class="fw-b mt-3">
#                                                             11:47 PM
#                                                         </div>
#                                                     </div>
#                                                     <div class="col-7 mt-3">
#                                                         <b style="color:#e60000;">Outbound</b>
#                                                         <div class="fw-light">
#                                                             Transit Center KTN GATEWAY
#                                                         </div>
#                                                                                                                                                                     </div>
#                                                 </div>
#                                                                                             <div class="row">
#                                                     <div class="col-4 text-end" style="border-right:1px solid #acacac;">
#                                                         <div class="fw-b mt-3">
#                                                             07:52 PM
#                                                         </div>
#                                                     </div>
#                                                     <div class="col-7 mt-3">
#                                                         <b style="color:#e60000;">Inbound</b>
#                                                         <div class="fw-light">
#                                                             Transit Center KTN GATEWAY
#                                                         </div>
#                                                                                                                                                                     </div>
#                                                 </div>
#                                                                                             <div class="row">
#                                                     <div class="col-4 text-end" style="border-right:1px solid #acacac;">
#                                                         <div class="fw-b mt-3">
#                                                             02:34 PM
#                                                         </div>
#                                                     </div>
#                                                     <div class="col-7 mt-3">
#                                                         <b style="color:#e60000;">Outbound</b>
#                                                         <div class="fw-light">
#                                                             Drop Point CDC CENTRAL PARK 319
#                                                         </div>
#                                                                                                                                                                     </div>
#                                                 </div>
#                                                                                             <div class="row">
#                                                     <div class="col-4 text-end" style="border-right:1px solid #acacac;">
#                                                         <div class="fw-b mt-3">
#                                                             02:29 PM
#                                                         </div>
#                                                     </div>
#                                                     <div class="col-7 mt-3">
#                                                         <b style="color:#e60000;">Outbound</b>
#                                                         <div class="fw-light">
#                                                             Drop Point CDC CENTRAL PARK 319
#                                                         </div>
#                                                                                                                                                                     </div>
#                                                 </div>
#                                                                                             <div class="row">
#                                                     <div class="col-4 text-end" style="border-right:1px solid #acacac;">
#                                                         <div class="fw-b mt-3">
#                                                             02:24 PM
#                                                         </div>
#                                                     </div>
#                                                     <div class="col-7 mt-3">
#                                                         <b style="color:#e60000;">Outbound</b>
#                                                         <div class="fw-light">
#                                                             Drop Point CDC CENTRAL PARK 319
#                                                         </div>
#                                                                                                                                                                     </div>
#                                                 </div>
#                                                                                             <div class="row">
#                                                     <div class="col-4 text-end" style="border-right:1px solid #acacac;">
#                                                         <div class="fw-b mt-3">
#                                                             02:23 PM
#                                                         </div>
#                                                     </div>
#                                                     <div class="col-7 mt-3">
#                                                         <b style="color:#e60000;">On Hold</b>
#                                                         <div class="fw-light">
#                                                             Drop Point CDC CENTRAL PARK 319
#                                                         </div>
#                                                                                                                                                                             <div>
#                                                                 (Sorted parcel wrongly)
#                                                             </div>
#                                                                                                             </div>
#                                                 </div>
#                                                                                             <div class="row">
#                                                     <div class="col-4 text-end" style="border-right:1px solid #acacac;">
#                                                         <div class="fw-b mt-3">
#                                                             02:23 PM
#                                                         </div>
#                                                     </div>
#                                                     <div class="col-7 mt-3">
#                                                         <b style="color:#e60000;">Delivery</b>
#                                                         <div class="fw-light">
#                                                             Drop Point CDC CENTRAL PARK 319
#                                                         </div>
#                                                                                                                                                                     </div>
#                                                 </div>
#                                                                                             <div class="row">
#                                                     <div class="col-4 text-end" style="border-right:1px solid #acacac;">
#                                                         <div class="fw-b mt-3">
#                                                             02:02 PM
#                                                         </div>
#                                                     </div>
#                                                     <div class="col-7 mt-3">
#                                                         <b style="color:#e60000;">Inbound</b>
#                                                         <div class="fw-light">
#                                                             Drop Point CDC CENTRAL PARK 319
#                                                         </div>
#                                                                                                                                                                     </div>
#                                                 </div>
#                                                                                             <div class="row">
#                                                     <div class="col-4 text-end" style="border-right:1px solid #acacac;">
#                                                         <div class="fw-b mt-3">
#                                                             11:21 AM
#                                                         </div>
#                                                     </div>
#                                                     <div class="col-7 mt-3">
#                                                         <b style="color:#e60000;">Outbound</b>
#                                                         <div class="fw-light">
#                                                             Transit Center KTN GATEWAY
#                                                         </div>
#                                                                                                                                                                     </div>
#                                                 </div>
#                                                                                             <div class="row">
#                                                     <div class="col-4 text-end" style="border-right:1px solid #acacac;">
#                                                         <div class="fw-b mt-3">
#                                                             10:33 AM
#                                                         </div>
#                                                     </div>
#                                                     <div class="col-7 mt-3">
#                                                         <b style="color:#e60000;">Inbound</b>
#                                                         <div class="fw-light">
#                                                             Transit Center KTN GATEWAY
#                                                         </div>
#                                                                                                                                                                     </div>
#                                                 </div>
#                                                                                     </div>
#                                                                             <div class=" row">
#                                             <div class="col-12 col-sm-4">
#                                                 <div class="text-sm-end fs-5 pt-3" style="color:#acacac;">
#                                                     2021-09-08, Wednesday
#                                                 </div>
#                                             </div>
#                                         </div>
#                                         <div class="container text-start p-1 pt-3" style="background: white;">
#                                                                                             <div class="row">
#                                                     <div class="col-4 text-end" style="border-right:1px solid #acacac;">
#                                                         <div class="fw-b mt-3">
#                                                             10:00 PM
#                                                         </div>
#                                                     </div>
#                                                     <div class="col-7 mt-3">
#                                                         <b style="color:#e60000;">Outbound</b>
#                                                         <div class="fw-light">
#                                                             Transit Center PJS GATEWAY
#                                                         </div>
#                                                                                                                                                                     </div>
#                                                 </div>
#                                                                                             <div class="row">
#                                                     <div class="col-4 text-end" style="border-right:1px solid #acacac;">
#                                                         <div class="fw-b mt-3">
#                                                             10:00 PM
#                                                         </div>
#                                                     </div>
#                                                     <div class="col-7 mt-3">
#                                                         <b style="color:#e60000;"> Load Truck</b>
#                                                         <div class="fw-light">
#                                                             Transit Center PJS GATEWAY
#                                                         </div>
#                                                                                                                                                                     </div>
#                                                 </div>
#                                                                                             <div class="row">
#                                                     <div class="col-4 text-end" style="border-right:1px solid #acacac;">
#                                                         <div class="fw-b mt-3">
#                                                             06:04 PM
#                                                         </div>
#                                                     </div>
#                                                     <div class="col-7 mt-3">
#                                                         <b style="color:#e60000;">Inbound</b>
#                                                         <div class="fw-light">
#                                                             Transit Center PJS GATEWAY
#                                                         </div>
#                                                                                                                                                                     </div>
#                                                 </div>
#                                                                                             <div class="row">
#                                                     <div class="col-4 text-end" style="border-right:1px solid #acacac;">
#                                                         <div class="fw-b mt-3">
#                                                             04:49 PM
#                                                         </div>
#                                                     </div>
#                                                     <div class="col-7 mt-3">
#                                                         <b style="color:#e60000;">Outbound</b>
#                                                         <div class="fw-light">
#                                                             Drop Point DP PORTKLANG 01
#                                                         </div>
#                                                                                                                                                                     </div>
#                                                 </div>
#                                                                                             <div class="row">
#                                                     <div class="col-4 text-end" style="border-right:1px solid #acacac;">
#                                                         <div class="fw-b mt-3">
#                                                             01:57 PM
#                                                         </div>
#                                                     </div>
#                                                     <div class="col-7 mt-3">
#                                                         <b style="color:#e60000;">Outbound</b>
#                                                         <div class="fw-light">
#                                                             Drop Point DP PORTKLANG 01
#                                                         </div>
#                                                                                                                                                                     </div>
#                                                 </div>
#                                                                                             <div class="row">
#                                                     <div class="col-4 text-end" style="border-right:1px solid #acacac;">
#                                                         <div class="fw-b mt-3">
#                                                             01:30 PM
#                                                         </div>
#                                                     </div>
#                                                     <div class="col-7 mt-3">
#                                                         <b style="color:#e60000;">Picked Up</b>
#                                                         <div class="fw-light">
#                                                             Drop Point DP PORTKLANG 01
#                                                         </div>
#                                                                                                                                                                     </div>
#                                                 </div>
#                                                                                     </div>
#                                                                     </div>
#                             </div>
#                         </div>
#
#                                                     <div class="d-grid gap-2 mt-4" style="border-radius:15px;">
#                                 <button class="btn btn-toggle-accordion accordion-header fw-bold"
#                                     style="background:white;color:#e60000;border-radius:15px;" type="button"
#                                     data-bs-toggle="collapse" data-bs-target="#collapse-0">
#                                     See More</button>
#                             </div>
#                                             </div>
#                 </div>
#                         </div>
#                             </div>
#         </div>
#     </div>
#
#     <div class="modal fade" id="modal-pod" tabindex="-1">
#         <div class="modal-dialog modal-dialog-centered">
#             <div class="modal-content">
#                 <div class="modal-header">
#                     <h5 class="modal-title">Proof of Delivery</h5>
#                     <button type="button" class="btn-close" data-bs-dismiss="modal" aria-label="Close"></button>
#                 </div>
#                 <div class="modal-body">
#                     <form id="form-pod">
#                         <p>
#                             Enter last 4 digits of sender/receiver phone number for verification
#                         </p>
#                         <div class="form-floating mb-3">
#                             <input type="text" class="form-control" id="phone" placeholder=" " name="phone" maxlength="4"
#                                 required pattern="\d*">
#                             <label for="phone"><span class="text-danger">*
#                                 </span>Last 4 digit</label>
#                             <p id="err-phone" class="text-danger err-text"></p>
#                         </div>
#                         <div class="text-center">
#                             <button id="btn-form-pod-submit" type="submit"
#                                 class="btn btn-primary">Verify</button>
#                         </div>
#                     </form>
#                     <div class="text-center">
#                         <img id="pod-img" class="w-100 h-100 mb-2" style="object-fit: scale-down" src="">
#                         <a id="pod-url" target="_blank"><button class="btn btn-primary">
#                                 <i class="fas fa-image me-2"></i>Open in new tab</button></a>
#                         <div id="pod-no-result">
#                             <p>pages/tracking.prrof_of_delivery_unavailable</p>
#                         </div>
#                     </div>
#                 </div>
#
#             </div>
#         </div>
#     </div>
#
#     <script>
#         var viewer = new Viewer(document.getElementById('pod-img'), {
#             title: false,
#             viewed() {
#                 // viewer.zoomTo(1);
#             },
#         });
#         var sender = "";
#         var receiver = "";
#         $('#form-tracking').submit(function(e) {
#             e.preventDefault();
#             $('#btn-form-tracking-submit').attr('disabled', '');
#             $('#btn-form-tracking-submit').html(
#                 '<span class="spinner-border spinner-border-sm" role="status" aria-hidden="true"></span><span class="visually-hidden">Loading...</span>'
#             );
#
#             $.ajax({
#                 type: "POST",
#                 url: "https://www.jtexpress.my/tracking",
#                 data: {
#                     "_token": "HJrY3QDtqXPGWb8sQxf35lb4bh5rCGJ1fhzsQUd6",
#                     "wb": $('#wb').val()
#                 },
#                 success: function(response) {
#                     $('#tracking-info').html(response);
#                     if (window.location.href.includes('tracking/')) {
#                         window.history.pushState('', '', './' + $('#wb').val());
#                     } else {
#                         window.history.pushState('', '', './tracking/' + $('#wb').val());
#                     }
#                 },
#                 error: function(data) {
#                     alert('Unknown Error Occured')
#                 },
#                 complete: function(data) {
#                     $('#btn-form-tracking-submit').removeAttr('disabled');
#                     $('#btn-form-tracking-submit').html('GO')
#                     progressBar();
#
#                 }
#             });
#         });
#         $('body').on('click', '.btn-pod', function(e) {
#             e.preventDefault();
#             $('#pod-url').css('display', 'none');
#             $('#pod-img').css('display', 'none');
#             $('#pod-img').attr('src', '');
#             $('#pod-no-result').css('display', 'none');
#             $('#form-pod').css('display', 'block');
#             $('#modal-pod').modal('show')
#             sender = $(this).attr('sender')
#             receiver = $(this).attr('receiver')
#             wb = $(this).attr('wb')
#         });
#         $('#form-pod').submit(function(e) {
#             $('.err-text').html('');
#             $('#btn-form-pod-submit').attr('disabled', '');
#             $('#btn-form-pod-submit').html(
#                 '<span class="spinner-border spinner-border-sm" role="status" aria-hidden="true"></span><span class="visually-hidden">Loading...</span>'
#             );
#             e.preventDefault();
#             $.ajax({
#                 type: "POST",
#                 url: "https://www.jtexpress.my/proof-of-delivery",
#                 data: {
#                     "_token": "HJrY3QDtqXPGWb8sQxf35lb4bh5rCGJ1fhzsQUd6",
#                     "wb": wb,
#                     "sender": sender,
#                     "receiver": receiver,
#                     "phone": $('#phone').val()
#                 },
#                 success: function(response) {
#                     if (response["status"] == "success") {
#                         $('#form-pod').css('display', 'none');
#                         if (response.url) {
#                             $('#modal-pod').modal('hide')
#                             $('#pod-img').attr('src', response.image);
#                             viewer.update()
#                             viewer.show();
#                             // $('#pod-url').attr('href', response.url);
#                             // $('#pod-img').css('display', 'block');
#                             // $('#pod-url').css('display', 'block');
#                             // $('.pod-result').css('display', 'block');
#                         } else {
#                             $('#pod-no-result').css('display', 'block');
#                         }
#                     } else {
#                         if (response["errors"]) {
#                             for (let input in response["errors"]) {
#                                 $('#err-' + input).html(response["errors"][input][0]);
#                             }
#                         }
#                     }
#
#
#                 },
#                 error: function(data) {
#                     alert('Unknown Error Occured')
#                 },
#                 complete: function(data) {
#                     $('#btn-form-pod-submit').removeAttr('disabled');
#                     $('#btn-form-pod-submit').html(
#                         'Verify'
#                     );
#                 }
#             });
#         });
#         $('body').on('click', '.btn-toggle-accordion', function(e) {
#             e.preventDefault();
#             let text = $(this).html().replace(/(\s|\r\n|\n|\r)/gm, "");
#             if (text == "SeeMore") {
#                 $(this).html("See Less")
#             } else {
#                 $(this).html("See More")
#             }
#         });
#         $(document).ready(function() {
#             progressBar();
#         });
#
#         function progressBar() {
#             $('ul').each(function() {
#                 if ($(this).hasClass('pickedup')) {
#                     $(this).find("li:first-child i").addClass('active');
#                     $(this).find("li:first-child img").addClass('active');
#                 } else if ($(this).hasClass('delivered')) {
#                     $(this).find("li i").addClass('active');
#                     $(this).find("li img").addClass('active');
#                 } else if ($(this).hasClass('delivery')) {
#                     $(this).find("li:nth-child(-n+3) i").addClass('active');
#                     $(this).find("li:nth-child(-n+3) img").addClass('active');
#                 } else {
#                     $(this).find("li:nth-child(-n+2) i").addClass('active');
#                     $(this).find("li:nth-child(-n+2) img").addClass('active');
#
#                 }
#             });
#         }
#     </script>
#             </div>
#         </div>
#         <footer class="text-center" id="footer"
#         style="background-color:#333333;color:white;position: absolute;bottom:0;left:0;right:0;width:100%;">
#         <div class="container-fluid">
#             <div class="container footer-page-link">
#
#                 <div class="row mx-auto" style="padding-top:10px">
#                     <div class="col-12 col-sm-3 text-start">
#                         <a href="https://www.jtexpress.my/about-us">About Us</a>
#                         <div class="custom-padding"><a
#                                 href="https://www.jtexpress.my/claim-form">Claim Support</a>
#                         </div>
#                     </div>
#                     <div class="col-12 col-sm-3 text-start">
#                         <a href="https://www.jtexpress.my/news"
#                             class="text-light">News</a>
#                         <div class="custom-padding"><a
#                                 href="https://www.jtexpress.my/faq">FAQ</a></div>
#                     </div>
#                     <div class="col-12 col-sm-3 text-start">
#                         <a href="https://www.jtexpress.my/legal"
#                             class="text-light">Terms of Use</a>
#
#                         <div class="custom-padding"><a
#                                 href="https://www.jtexpress.my/customer-guide/1">Packaging Guide</a>
#                         </div>
#                     </div>
#                     <div class="col-12 col-sm-2 col-md-2 col-lg-2 col-xl-2 text-start">
#                         <a href="https://www.jtexpress.my/crm"
#                             class="text-light">Complaint Centre</a>
#                     </div>
#                 </div>
#             </div>
#             <hr class="mx-auto" style="width:83%">
#             <div class="row" style="padding-top:10px">
#                 <div class="col-12 col-sm-12 col-md-4 col-lg-4 col-xl-4">
#                     <div class="text-light">Follow Us</div>
#                     <div class="d-flex justify-content-center" style="font-size: 2em;">
#                         <div class="px-1">
#                             <a href="https://www.facebook.com/jntexpressmalaysia" target="_blank">
#                                 <i class="fab fa-facebook-square socmed"></i>
#                             </a>
#                         </div>
#                         <div class="px-1">
#                             <a href="https://www.instagram.com/jtexpressmy/" target="_blank">
#                                 <i class="fab fa-instagram socmed"></i>
#                             </a>
#                         </div>
#                         <div class="px-1">
#                             <a href="https://twitter.com/jntexpressmy" target="_blank">
#                                 <i class="fab fa-twitter-square socmed"></i>
#                             </a>
#                         </div>
#                         <div class="px-1">
#                             <a href="https://www.youtube.com/channel/UCZfbIi4QdozEtl_fvEXbvcQ" target="_blank">
#                                 <i class="fab fa-youtube-square socmed"></i>
#                             </a>
#                         </div>
#                         <div class="px-1">
#                             <a href="https://malaysia.cr-cts.com/weixin" target="_blank">
#                                 <i class="fab fa-weixin socmed"></i>
#                             </a>
#                         </div>
#
#                     </div>
#                 </div>
#
#                 <div class="col-12 col-sm-12 col-md-4 col-lg-4 col-xl-4">
#                     <div class="text-light">J&amp;T Express International</div>
#                     <div>
#                         <a href="https://www.jtexpress.com.cn/aboutUs.html" target="_blank">
#                             <img src="https://www.jtexpress.my/icon/icon-1.png" class="px-1"
#                                 style="height:30px;width:30px;object-fit:scale-down">
#                         </a>
#                         <a href="http://www.jet.co.id/" target="_blank">
#                             <img src="https://www.jtexpress.my/icon/icon-2.png" class="px-1"
#                                 style="height:30px;width:30px;object-fit:scale-down">
#                         </a>
#                         <a href="https://jtexpress.vn/" target="_blank">
#                             <img src="https://www.jtexpress.my/icon/icon-3.png" class="px-1"
#                                 style="height:30px;width:30px;object-fit:scale-down">
#                         </a>
#                         <a href="https://jtexpress.co.th/" target="_blank">
#                             <img src="https://www.jtexpress.my/icon/icon-4.png" class="px-1"
#                                 style="height:30px;width:30px;object-fit:scale-down">
#                         </a>
#                         <a href="http://www.jtexpress.ph/" target="_blank">
#                             <img src="https://www.jtexpress.my/icon/icon-5.png" class="px-1"
#                                 style="height:30px;width:30px;object-fit:scale-down">
#                         </a>
#                         <a href="https://www.jtexpress.com.kh/" target="_blank">
#                             <img src="https://www.jtexpress.my/icon/icon-6.png" class="px-1"
#                                 style="height:30px;width:30px;object-fit:scale-down">
#                         </a>
#                         <a href="https://www.jtexpress.sg/" target="_blank">
#                             <img src="https://www.jtexpress.my/icon/icon-7.png" class="px-1"
#                                 style="height:30px;width:30px;object-fit:scale-down">
#                         </a>
#                     </div>
#                 </div>
#                 <div class="col-12 col-sm-12 col-md-4 col-lg-4 col-xl-4">
#                     <div class="text-light">Download Our App</div>
#                     <div class="d-flex justify-content-center">
#                         <a href="https://itunes.apple.com/my/app/j-t-malaysia/id1375858773?mt=8" target="_blank">
#                             <img src="https://www.jtexpress.my/img/app-store.png"
#                                 style="height:50px;width:120px;object-fit:scale-down">
#                         </a>
#                         <a href="https://play.google.com/store/apps/details?id=com.jtexpress.MyClient&hl=en"
#                             target="_blank">
#                             <img src="https://www.jtexpress.my/img/gplay.png"
#                                 style="height:50px;width:120px;object-fit:scale-down">
#                         </a>
#                     </div>
#                 </div>
#             </div>
#             <div class="row" style="padding-top:10px">
#                 <div class="col-12 col-sm-12 col-md-12 col-lg-12 col-xl-12" style="background-color:#212528;">
#                     <div>J&amp;T Express (Malaysia) SDN BHD All Rights Reserved © 2018-2021</div>
#                 </div>
#             </div>
#         </div>
#     </footer>
#         <div id="cention-chat-container"></div>
#         <script>
#             $('#wrapper').css('padding-bottom', $('#footer').css('height'));
#             // var myVar;
#
#             // function loader() {
#             //     myVar = setTimeout(showPage, 10);
#             // }
#
#             // function showPage() {
#             //     document.getElementById("loader").style.display = "none";
#             // }
#
#             const $dropdown = $(".dropdown");
#             const $dropdownToggle = $(".dropdown-toggle");
#             const $dropdownMenu = $(".dropdown-menu");
#             const showClass = "show";
#
#             $(window).on("load resize", function() {
#                 if (this.matchMedia("(min-width: 768px)").matches) {
#                     $dropdown.hover(
#                         function() {
#                             const $this = $(this);
#                             $this.addClass(showClass);
#                             $this.find($dropdownToggle).attr("aria-expanded", "true");
#                             $this.find($dropdownMenu).addClass(showClass);
#                         },
#                         function() {
#                             const $this = $(this);
#                             $this.removeClass(showClass);
#                             $this.find($dropdownToggle).attr("aria-expanded", "false");
#                             $this.find($dropdownMenu).removeClass(showClass);
#                         }
#                     );
#                 } else {
#                     $dropdown.off("mouseenter mouseleave");
#                 }
#             });
#         </script>
#
#
#         <script type="text/javascript">
#             var CentionBaseURL = "https://jtexpress.cust.cention.se";
#         </script>
#         <script src="https://jtexpress.cust.cention.se/cention/chat/js/widget.js" type="text/javascript"></script>
#         <script>
#             // LIVE CHAT
#             if (typeof CentionChat !== "undefined") {
#                 CentionChat("cention-chat-container", {
#                     areaId: [{
#                             "id": 7,
#                             "name": "Johor"
#                         },
#                         {
#                             "id": 4,
#                             "name": "Kelantan / Terengganu"
#                         },
#                         {
#                             "id": 6,
#                             "name": "Kuala Lumpur"
#                         },
#                         {
#                             "id": 8,
#                             "name": "Melaka / Negeri Sembilan"
#                         },
#                         {
#                             "id": 2,
#                             "name": "Pahang"
#                         },
#                         {
#                             "id": 5,
#                             "name": "Perak"
#                         },
#                         {
#                             "id": 1,
#                             "name": "Perlis / Kedah / Penang"
#                         },
#                         {
#                             "id": 9,
#                             "name": "Sabah"
#                         },
#                         {
#                             "id": 10,
#                             "name": "Sarawak"
#                         },
#                         {
#                             "id": 11,
#                             "name": "Klang, Kuala Langat, Petaling Jaya, Putrajaya, Sepang"
#                         },
#                         {
#                             "id": 3,
#                             "name": "Gombak, Hulu Selangor, Hulu Langat, Kuala Selangor, Sabak Bernam"
#                         },
#                     ],
#                 });
#             }
#         </script>
#     </div>
#
# </body>
#
# </html>

# %%
innerHtml= r.text

# %%
soup = BeautifulSoup(innerHtml, 'html.parser')

# %%
body=soup.find(class_="accordion-body")

# %%
alert=soup.find(class_="alert")
if alert:
    print('Sorry, information not found')

# %%
status_history=[]

# %%
for parent in body.findChildren(recursive=False):
    children=parent.findChildren(recursive=False)
    dated_status_obj={}
    for n, child in enumerate(children):
        if (n % 2) == 0:
            #even dates
            date=child.text.strip()
#             print(date)
            dated_status_obj={'date':date}
            
        else:
            #odd time statuses and locations
            history = child.find_all(class_="row")
            statuses=[]
            for a_status in history:

                time=a_status.find(class_="fw-b mt-3").text.strip()
                status=a_status.find("b").text.strip()
                location=a_status.find(class_="fw-light").text.strip()
#                 print(f'{time} {status} {location}')
                
                status_obj={'time':time,'status':status,'location':location}
                statuses.append(status_obj)
                
            dated_status_obj['statuses']=statuses
            status_history.append(dated_status_obj)
            
print(status_history)
# Out:
# [{'date': '2021-09-10, Friday', 'statuses': [{'time': '05:34 PM', 'status': 'Delivered', 'location': 'Drop Point CDC GAUNG LATI 327'}, {'time': '10:57 AM', 'status': 'Delivery', 'location': 'Drop Point CDC GAUNG LATI 327'}, {'time': '09:11 AM', 'status': 'Inbound', 'location': 'Drop Point CDC GAUNG LATI 327'}]}, {'date': '2021-09-09, Thursday', 'statuses': [{'time': '11:47 PM', 'status': 'Outbound', 'location': 'Transit Center KTN GATEWAY'}, {'time': '07:52 PM', 'status': 'Inbound', 'location': 'Transit Center KTN GATEWAY'}, {'time': '02:34 PM', 'status': 'Outbound', 'location': 'Drop Point CDC CENTRAL PARK 319'}, {'time': '02:29 PM', 'status': 'Outbound', 'location': 'Drop Point CDC CENTRAL PARK 319'}, {'time': '02:24 PM', 'status': 'Outbound', 'location': 'Drop Point CDC CENTRAL PARK 319'}, {'time': '02:23 PM', 'status': 'On Hold', 'location': 'Drop Point CDC CENTRAL PARK 319'}, {'time': '02:23 PM', 'status': 'Delivery', 'location': 'Drop Point CDC CENTRAL PARK 319'}, {'time': '02:02 PM', 'status': 'Inbound', 'location': 'Drop Point CDC CENTRAL PARK 319'}, {'time': '11:21 AM', 'status': 'Outbound', 'location': 'Transit Center KTN GATEWAY'}, {'time': '10:33 AM', 'status': 'Inbound', 'location': 'Transit Center KTN GATEWAY'}]}, {'date': '2021-09-08, Wednesday', 'statuses': [{'time': '10:00 PM', 'status': 'Outbound', 'location': 'Transit Center PJS GATEWAY'}, {'time': '10:00 PM', 'status': 'Load Truck', 'location': 'Transit Center PJS GATEWAY'}, {'time': '06:04 PM', 'status': 'Inbound', 'location': 'Transit Center PJS GATEWAY'}, {'time': '04:49 PM', 'status': 'Outbound', 'location': 'Drop Point DP PORTKLANG 01'}, {'time': '01:57 PM', 'status': 'Outbound', 'location': 'Drop Point DP PORTKLANG 01'}, {'time': '01:30 PM', 'status': 'Picked Up', 'location': 'Drop Point DP PORTKLANG 01'}]}]

# %%
direction=soup.find(class_="col-12 text-start").text.strip().split()
print(direction)
# Out:
# ['SELANGOR', 'KELANTAN']

# %%
try:
    origin=direction[0]
except:
    origin=None

try:
    destination=direction[1]
except:
    destination=None
    
status=soup.find(class_="text-center mx-auto mb-3 fw-light h3").text.strip()

# %%
return_obj={'tnum':tnum,'origin':origin,'destination':destination,'status':status,'status_history':status_history}

# %%
print(return_obj)
# Out:
# {'tnum': 620000295758173, 'origin': 'SELANGOR', 'destination': 'KELANTAN', 'status': 'Delivered', 'status_history': [{'date': '2021-09-10, Friday', 'statuses': [{'time': '05:34 PM', 'status': 'Delivered', 'location': 'Drop Point CDC GAUNG LATI 327'}, {'time': '10:57 AM', 'status': 'Delivery', 'location': 'Drop Point CDC GAUNG LATI 327'}, {'time': '09:11 AM', 'status': 'Inbound', 'location': 'Drop Point CDC GAUNG LATI 327'}]}, {'date': '2021-09-09, Thursday', 'statuses': [{'time': '11:47 PM', 'status': 'Outbound', 'location': 'Transit Center KTN GATEWAY'}, {'time': '07:52 PM', 'status': 'Inbound', 'location': 'Transit Center KTN GATEWAY'}, {'time': '02:34 PM', 'status': 'Outbound', 'location': 'Drop Point CDC CENTRAL PARK 319'}, {'time': '02:29 PM', 'status': 'Outbound', 'location': 'Drop Point CDC CENTRAL PARK 319'}, {'time': '02:24 PM', 'status': 'Outbound', 'location': 'Drop Point CDC CENTRAL PARK 319'}, {'time': '02:23 PM', 'status': 'On Hold', 'location': 'Drop Point CDC CENTRAL PARK 319'}, {'time': '02:23 PM', 'status': 'Delivery', 'location': 'Drop Point CDC CENTRAL PARK 319'}, {'time': '02:02 PM', 'status': 'Inbound', 'location': 'Drop Point CDC CENTRAL PARK 319'}, {'time': '11:21 AM', 'status': 'Outbound', 'location': 'Transit Center KTN GATEWAY'}, {'time': '10:33 AM', 'status': 'Inbound', 'location': 'Transit Center KTN GATEWAY'}]}, {'date': '2021-09-08, Wednesday', 'statuses': [{'time': '10:00 PM', 'status': 'Outbound', 'location': 'Transit Center PJS GATEWAY'}, {'time': '10:00 PM', 'status': 'Load Truck', 'location': 'Transit Center PJS GATEWAY'}, {'time': '06:04 PM', 'status': 'Inbound', 'location': 'Transit Center PJS GATEWAY'}, {'time': '04:49 PM', 'status': 'Outbound', 'location': 'Drop Point DP PORTKLANG 01'}, {'time': '01:57 PM', 'status': 'Outbound', 'location': 'Drop Point DP PORTKLANG 01'}, {'time': '01:30 PM', 'status': 'Picked Up', 'location': 'Drop Point DP PORTKLANG 01'}]}]}
